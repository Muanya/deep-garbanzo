# %% [markdown]
# <a href="https://colab.research.google.com/github/Muanya/deep-garbanzo/blob/main/course1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world')
# Out:
# Hello world

# %%
from google.colab import drive
drive.mount('/content/drive')
